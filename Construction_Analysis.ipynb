# %% [markdown]
# <a href="https://colab.research.google.com/github/bjudson22/New_Construction_Trends/blob/main/Construction_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('/content/USGV.csv')

# %%
df.head(100)
# Out:
#     per_idx    per_name  cat_idx cat_code  \
# 0         1  2002-01-01        1     XXXX
# 1         1  2002-01-01        2     00XX
# 2         1  2002-01-01        3     NRXX
# 3         1  2002-01-01        4     01XX
# 4         1  2002-01-01        5     02XX
# ..      ...         ...      ...      ...
# 95        1  2002-01-01       37    A15XX
# 96        2  2002-02-01        1     XXXX
# 97        2  2002-02-01        2     00XX
# 98        2  2002-02-01        3     NRXX
# 99        2  2002-02-01        4     01XX
#
#                                         cat_desc  cat_indent  dt_idx dt_code  \
# 0                             Total Construction           0       1       T
# 1                                    Residential           0       1       T
# 2                                 Nonresidential           0       1       T
# 3                                        Lodging           1       1       T
# ...

# %%
df.shape
# Out:
# (50208, 20)

# %%
df.describe(include='all')
# Out:
#              per_idx    per_name       cat_idx cat_code            cat_desc  \
# count   50208.000000       50208  50208.000000    50208               50208
# unique           NaN         177           NaN       38                  38
# top              NaN  2009-05-01           NaN     XXXX  Total Construction
# freq             NaN         288           NaN     2091                2091
# mean       90.317400         NaN     15.693555      NaN                 NaN
# std        50.352974         NaN     10.449870      NaN                 NaN
# min         1.000000         NaN      1.000000      NaN                 NaN
# 25%        47.000000         NaN      7.000000      NaN                 NaN
# 50%        90.000000         NaN     14.000000      NaN                 NaN
# 75%       134.000000         NaN     24.000000      NaN                 NaN
# max       177.000000         NaN     38.000000      NaN                 NaN
#
# ...

# %%
print(df['dt_desc'].unique())
# Out:
# ['Total Construction' 'Total Private Construction'
#  'Total Public Construction'
#  'Monthly Percent Change for Total Construction'
#  'Monthly Percent Change for Private Construction'
#  'Monthly Percent Change for Public Construction' nan]

# %%
print(df['cat_desc'].unique())
# Out:
# ['Total Construction' 'Residential' 'Nonresidential' 'Lodging' 'Office'
#  'Commercial' 'Health Care' 'Educational' 'Religious' 'Public Safety'
#  'Amusement and Recreation' 'Transportation' 'Communication' 'Power'
#  'Highway and Street' 'Sewage and Waste Disposal' 'Water Supply'
#  'Conservation and Development' 'Manufacturing'
#  'Annual Rate for Total Construction' 'Annual Rate for Residential'
#  'Annual Rate for Nonresidential' 'Annual Rate for Lodging'
#  'Annual Rate for Office' 'Annual Rate for Commercial'
#  'Annual Rate for Health Care' 'Annual Rate for Educational'
#  'Annual Rate for Religious' 'Annual Rate for Public Safety'
#  'Annual Rate for Amusement and Recreation'
#  'Annual Rate for Transportation' 'Annual Rate for Communication'
#  'Annual Rate for Power' 'Annual Rate for Highway and Street'
#  'Annual Rate for Sewage and Waste Disposal'
#  'Annual Rate for Water Supply'
#  'Annual Rate for Conservation and Development'
#  'Annual Rate for Manufacturing']
